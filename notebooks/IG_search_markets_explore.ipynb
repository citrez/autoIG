# %% [raw]
# This notebook need cleaning. Not sure of the objective
#
# This notebook should be for looking into epics that are good potential condidates for my models.
# Identifying features which would be nice, such as the epic being tradeable 24/7.
#
# Or the historical prices having certain smoothness.

# %%
from datetime import datetime
import pandas as pd
import numpy as np
from trading_ig.rest import IGService
from trading_ig.config import config
import yfinance as yf
from autoIG.epics import BITCOIN_EPIC,US_CRUDE_OIL_EPIC

# %%
ig_service = IGService(config.username, config.password, config.api_key)
ig = ig_service.create_session()

# %%
## Search for a market

# %%
# initates_list = [
#     "AllianceBernstein Holding",
#     "LiqTech International",
#     "Amadeus IT Group",
#     "Plantronics",
#     "Aerojet Rocketdyne"
#     ]
# results  = pd.concat([ ig_service.search_markets(search_term = s) for s in initates_list],axis = 0)
# results  = results.query("expiry == 'DFB'")
# results

# %%
nasdaq = pd.read_csv("../resources/nasdaq.csv")
nasdaq.head(1)
# Out:
#   Symbol                                    Name Last Sale  Net Change  \
# 0      A  Agilent Technologies Inc. Common Stock   $130.55         6.7
#
#   % Change    Market Cap        Country  IPO Year   Volume       Sector  \
# 0    5.41%  3.903445e+10  United States    1999.0  2698841  Industrials
#
#               Industry
# 0  Electrical Products

# %%
## Get info about a market

# %%
# market = ig_service.fetch_market_by_epic(BITCOIN_EPIC)
"L1:CS.D.GBPUSD.TODAY.IP"
ig_service.search_markets("L1:")
# Out:
#                     epic            instrumentName instrumentType  expiry  \
# 0     KA.D.LLOY.DAILY.IP  Lloyds Banking Group PLC         SHARES     DFB
# 1       KA.D.LLOY.DEC.IP  Lloyds Banking Group PLC         SHARES  DEC-22
# 2       KA.D.LLOY.MAR.IP  Lloyds Banking Group PLC         SHARES  MAR-23
# 3       KA.D.LLOY.JUN.IP  Lloyds Banking Group PLC         SHARES  JUN-23
# 4     EN.D.LCO.Month5.IP         Oil - Brent Crude    COMMODITIES  FEB-23
# 5     EN.D.LCO.Month6.IP         Oil - Brent Crude    COMMODITIES  MAR-23
# 6        CC.D.LCO.USS.IP         Oil - Brent Crude    COMMODITIES     DFB
# 7   CS.D.GBPUSD.TODAY.IP                   GBP/USD     CURRENCIES     DFB
# 8   CS.D.LTCUSD.TODAY.IP                  Litecoin     CURRENCIES     DFB
# 9   EC.D.UDISFP.DAILY.IP                       U10         SHARES     DFB
# 10    EC.D.UDISFP.DEC.IP                       U10         SHARES  DEC-22
# 11    EC.D.UDISFP.MAR.IP                       U10         SHARES  MAR-23
# 12    EC.D.UDISFP.JUN.IP                       U10         SHARES  JUN-23
# 13  CS.D.EURGBP.TODAY.IP                   EUR/GBP     CURRENCIES     DFB
# 14    IR.D.FLG.Month2.IP                 Long Gilt          RATES  MAR-23
# 15  CS.D.USDCAD.TODAY.IP                   USD/CAD     CURRENCIES     DFB
# 16  CS.D.GBPJPY.TODAY.IP                   GBP/JPY     CURRENCIES     DFB
# 17    SA.D.AHUS.DAILY.IP                R1 RCM Inc         SHARES     DFB
# 18      SA.D.AHUS.DEC.IP                R1 RCM Inc         SHARES  DEC-22
# 19      SA.D.AHUS.MAR.IP                R1 RCM Inc         SHARES  MAR-23
# 20      SA.D.AHUS.JUN.IP                R1 RCM Inc         SHARES  JUN-23
# 21        CC.D.CL.USS.IP            Oil - US Crude    COMMODITIES     DFB
# 22  CS.D.GBPAUD.TODAY.IP                   GBP/AUD     CURRENCIES     DFB
# 23  CS.D.GBPEUR.TODAY.IP                   GBP/EUR     CURRENCIES     DFB
# 24  UB.D.FRZAUS.DAILY.IP              Forza X1 Inc         SHARES     DFB
# 25    UB.D.FRZAUS.DEC.IP              Forza X1 Inc         SHARES  DEC-22
# 26    UB.D.FRZAUS.MAR.IP              Forza X1 Inc         SHARES  MAR-23
# 27    UB.D.FRZAUS.JUN.IP              Forza X1 Inc         SHARES  JUN-23
# 28  UB.D.LHCGUS.DAILY.IP             LHC Group Inc         SHARES     DFB
# 29    UB.D.LHCGUS.DEC.IP             LHC Group Inc         SHARES  DEC-22
# 30    UB.D.LHCGUS.MAR.IP             LHC Group Inc         SHARES  MAR-23
# 31    UB.D.LHCGUS.JUN.IP             LHC Group Inc         SHARES  JUN-23
# 32   ED.D.M12GY.DAILY.IP            M1 Kliniken AG         SHARES     DFB
# 33     ED.D.M12GY.DEC.IP            M1 Kliniken AG         SHARES  DEC-22
# 34     ED.D.M12GY.MAR.IP            M1 Kliniken AG         SHARES  MAR-23
#
#          high        low  percentageChange  netChange updateTime  \
# 0      46.647     46.024             -0.16     -0.075   16:30:00
# 1      46.751     46.035             -0.16     -0.075   16:30:00
# 2      47.217     46.308             -0.16     -0.075   16:30:00
# 3      47.746     46.640             -0.16     -0.075   16:30:00
# 4    8052.000   7767.000             -0.93    -74.000   16:30:06
# 5    8082.000   7794.000             -0.99    -79.000   16:30:06
# 6    8058.800   7777.200             -0.93    -73.900   16:30:06
# 7   12227.200  12105.500              0.35     42.400   16:30:06
# 8      80.700     75.200             -3.05     -2.400   16:30:04
# 9         NaN        NaN              0.00      0.000   16:30:00
# 10        NaN        NaN              0.00      0.000   16:30:00
# 11        NaN        NaN              0.00      0.000   16:30:00
# 12        NaN        NaN              0.00      0.000   16:30:00
# 13   8644.000   8608.600             -0.12    -10.000   16:30:05
# 14  10681.000  10593.000              0.35     37.500   16:30:00
# 15  13700.700  13587.200             -0.08    -11.100   16:30:06
# 16  16744.600  16594.800              0.15     24.700   16:30:06
# 17   1021.000    966.000              1.30     12.500   16:30:03
# 18   1024.700    965.600              1.29     12.500   16:30:03
# 19   1036.100    974.400              1.29     12.500   16:30:03
# 20   1049.800    984.400              1.27     12.500   16:30:03
# 21   7549.600   7255.700             -1.35   -100.800   16:30:06
# 22  18245.100  18084.400              0.06     11.600   16:30:06
# 13    TRADEABLE              1
# 14    TRADEABLE              1
# 15    TRADEABLE              1
# 16    TRADEABLE              1
# 17    TRADEABLE              1
# 18    TRADEABLE              1
# 19    TRADEABLE              1
# 20    TRADEABLE              1
# 21    TRADEABLE              1
# 22    TRADEABLE              1
# 23    TRADEABLE              1
# 24    TRADEABLE              1
# 25    TRADEABLE              1
# 26    TRADEABLE              1
# 27    TRADEABLE              1
# 28    TRADEABLE              1
# 29    TRADEABLE              1
# 30    TRADEABLE              1
# 31    TRADEABLE              1
# 32   ON_AUCTION              1
# 33   ON_AUCTION              1
# 34   ON_AUCTION              1

# %%
from autoIG.utils import market_series

# %%
market_instrument,market_dealingrules,market_snapshot = market_series(ig_service.fetch_market_by_epic('CS.D.GBPUSD.TODAY.IP'))

# %%
market_instrument
# Out:
# epic                                                           CS.D.GBPUSD.TODAY.IP
# expiry                                                                          DFB
# name                                                                        GBP/USD
# forceOpenAllowed                                                               True
# stopsLimitsAllowed                                                             True
# lotSize                                                                         1.0
# unit                                                                         AMOUNT
# type                                                                     CURRENCIES
# controlledRiskAllowed                                                          True
# streamingPricesAvailable                                                       True
# marketId                                                                     GBPUSD
# currencies                        [{'code': 'USD', 'symbol': '$', 'baseExchangeR...
# sprintMarketsMinimumExpiryTime                                                 None
# sprintMarketsMaximumExpiryTime                                                 None
# marginDepositBands                [{'min': 0, 'max': 105, 'margin': 3.33, 'curre...
# marginFactor                                                                   3.33
# marginFactorUnit                                                         PERCENTAGE
# slippageFactor                                       {'unit': 'pct', 'value': 50.0}
# limitedRiskPremium                                 {'value': 2.5, 'unit': 'POINTS'}
# openingHours                                                                   None
# expiryDetails                     {'lastDealingDate': '2029-04-06T19:00', 'settl...
# rolloverDetails                                                                None
# newsCode                                                                       GBP=
# chartCode                                                                    GBPUSD
# country                                                                        None
# valueOfOnePip                                                                  None
# onePipMeans                                                                    None
# contractSize                                                                   None
# specialInfo                       [DEFAULT KNOCK OUT LEVEL DISTANCE, MIN KNOCK O...
# dtype: object

# %%
def check_streamingPricesAvailable(m):
    """Check if an market epic has streaming prices"""
    return m.instrument.streamingPricesAvailable

check_streamingPricesAvailable(market)
# Out:
# True

# %%
results_config = {
    "resolution": "M",
    "start_date": "2019-07-17",
    "end_date": "2020-01-17",
}
result = ig_service.fetch_historical_prices_by_epic(
    BITCOIN_EPIC,
    **results_config
    )
result['prices'].head(2)
# Out:
#                bid                               ask                           \
#               Open     High     Low   Close     Open     High     Low   Close
# DateTime
# 2019-08-01  9994.2  12298.3  9307.3  9608.0  10034.2  12338.3  9347.3  9648.0
# 2019-09-01  9611.1  10920.4  7692.6  8223.7   9651.1  10960.4  7728.6  8259.7
#
#            last
#            Open High Low Close   Volume
# DateTime
# 2019-08-01  NaN  NaN NaN   NaN  3101614
# 2019-09-01  NaN  NaN NaN   NaN  2582615
