# %% [raw]
# This notebook explores the yahoo finance api
#
# This covers:
# -Set up a ticker
# - Look at recomendations for that ticker
# - Look at information provided (such as industry, full time employees etc)

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from autoIG import tickers

# %%
gold = yf.Ticker(tickers.GOLD_TICKER)
msft = yf.Ticker(tickers.MSFT_TICKER)

# %%
# we can get industry recomendations
msft.recommendations
# Out:
#                                    Firm       To Grade From Grade Action
# Date
# 2012-03-16 08:19:00      Argus Research            Buy                up
# 2012-03-19 14:00:00      Hilliard Lyons  Long-Term Buy              main
# 2012-03-22 07:03:00      Morgan Stanley     Overweight              main
# 2012-04-03 11:53:00                 UBS            Buy              main
# 2012-04-20 06:18:00       Deutsche Bank            Buy              main
# ...                                 ...            ...        ...    ...
# 2022-10-26 12:58:51      Wolfe Research     Outperform              main
# 2022-10-26 13:25:50  Evercore ISI Group     Outperform              main
# 2022-10-26 13:28:29         BMO Capital     Outperform              main
# 2022-10-27 11:14:36          Rosenblatt            Buy              main
# 2022-11-02 10:29:21           Macquarie        Neutral              init
#
# [424 rows x 4 columns]

# %%
# information
import pprint
print(f"Size of info dictionary: {len(msft.info.keys())}")
pprint.pprint(msft.info,indent = 2)
# Out:
# Size of info dictionary: 154
# { '52WeekChange': -0.26470673,
#   'SandP52WeekChange': -0.14731997,
#   'address1': 'One Microsoft Way',
#   'algorithm': None,
#   'annualHoldingsTurnover': None,
#   'annualReportExpenseRatio': None,
#   'ask': 247.11,
#   'askSize': 1200,
#   'averageDailyVolume10Day': 34117060,
#   'averageVolume': 28509043,
#   'averageVolume10days': 34117060,
#   'beta': 0.91984,
#   'beta3Year': None,
#   'bid': 246.87,
#   'bidSize': 900,
#   'bookValue': 23.276,
#   'category': None,
#   'circulatingSupply': None,
#   'city': 'Redmond',
#   'coinMarketCapLink': None,
#   'companyOfficers': [],
#   'country': 'United States',
#   'currency': 'USD',
#   'currentPrice': 247.11,
#   'currentRatio': 1.84,
#   'dateShortInterest': 1667174400,
#   'dayHigh': 247.99,
#   'dayLow': 242.32,
#   'debtToEquity': 44.442,
#   'dividendRate': 2.72,
#   'dividendYield': 0.011,
#   'earningsGrowth': -0.133,
#   'earningsQuarterlyGrowth': -0.144,
#   'ebitda': 98841001984,
# ...

# %%
# Stock splits
msft.actions.head()
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-09-21 00:00:00-04:00        0.0           2.0
# 1990-04-16 00:00:00-04:00        0.0           2.0
# 1991-06-27 00:00:00-04:00        0.0           1.5
# 1992-06-15 00:00:00-04:00        0.0           1.5
# 1994-05-23 00:00:00-04:00        0.0           2.0

# %%
history_raw = gold.history()
# history_raw.to_csv('tmp/history_raw.csv')

# %%
def mutate_history(df):
    df['days_since'] =(df.index - df.index[0]).days
    return df
history = mutate_history(history_raw)
history.head(3)
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2022-10-13 00:00:00-04:00  1675.199951  1675.300049  1641.500000  1670.000000
# 2022-10-14 00:00:00-04:00  1665.300049  1667.000000  1640.000000  1641.699951
# 2022-10-17 00:00:00-04:00  1650.199951  1657.000000  1646.800049  1657.000000
#
#                            Volume  Dividends  Stock Splits  days_since
# Date
# 2022-10-13 00:00:00-04:00     729          0             0           0
# 2022-10-14 00:00:00-04:00      82          0             0           1
# 2022-10-17 00:00:00-04:00     238          0             0           4
