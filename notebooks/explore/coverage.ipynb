# %%
from autoIG.utils import ROOT_DIR
import pandas as pd
import numpy as np

bezinga_analyst_ratings = pd.read_csv(ROOT_DIR.parent/'data/bezinga_analyst_ratings.csv')
bezinga_analyst_ratings = bezinga_analyst_ratings.set_index('Date')
bezinga_analyst_ratings
# Out:
#                                 Ticker  Company Current Price  \
# Date
# 12/23/2022      ARRYArray Technologies   $20.49        26.89%
# 12/23/2022            NUTXNutex Health    $2.08        44.23%
# 12/23/2022             FSLRFirst Solar  $156.75        11.64%
# 12/23/2022  SEDGSolarEdge Technologies  $310.15         4.79%
# 12/23/2022         MMCMarsh & McLennan  $165.58        -5.18%
# ...                                ...      ...           ...
# 12/16/2022                 PCVXVaxcyte   $46.67        28.56%
# 12/16/2022               CSGPCoStar Gr   $76.89        43.06%
# 12/16/2022       PAYPaymentus Holdings    $7.15        53.85%
# 12/16/2022       CYBRCyberArk Software  $124.35        40.73%
# 12/16/2022          STRSitio Royalties   $29.44        22.28%
#
#               Upside/Downside      Analyst Firm Analyst & % Accurate  \
# Date
# 12/23/2022  Cantor Fitzgerald   Derek Soderberg                → $26
# ...
